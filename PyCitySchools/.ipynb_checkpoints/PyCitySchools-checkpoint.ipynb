# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#total_schools = len(school_data)
#len(school_data_complete)
#total_budget = school_data["budget"].sum()
#avg_math_score = student_data["math_score"].mean()
#avg_math_score
#avg_reading_score = student_data["reading_score"].mean()


#math_pass = len(student_data[student_data["math_score"] >= 70])/len(school_data_complete)*100
#math_pass 

#reading_pass = len(student_data[student_data["reading_score"] >= 70])/len(school_data_complete)*100
#reading_pass 

overall_pass = len(student_data[student_data["math_score"]]) & len(student_data[student_data["reading_score"] >= 70]/len(school_data_complete)*100
overall_pass
# Out:
#   File "C:\Users\camer\AppData\Local\Temp\ipykernel_7012\3297191521.py", line 16
#     overall_pass
#     ^
# SyntaxError: invalid syntax

# %%
school_data_complete.loc[:,["school name", "math grade"]]

#consolidated_data = school_data_complete.iloc[0:2, 0:5]
#print(consolidated_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7012\1747770521.py in <module>
# ----> 1 school_data_complete.loc[:,["school name", "math grade"]]
#       2
#       3 #consolidated_data = school_data_complete.iloc[0:2, 0:5]
#       4 #print(consolidated_data)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
# ...
